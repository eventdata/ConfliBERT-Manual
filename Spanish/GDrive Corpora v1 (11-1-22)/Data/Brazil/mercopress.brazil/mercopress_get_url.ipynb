# %%
# !pip install pandarallel
import pandas as pd
pd.set_option("max_colwidth", 600)
from bs4 import BeautifulSoup
import requests

from pandarallel import pandarallel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pandarallel: filename=pandarallel-1.6.1-py3-none-any.whl size=16265 sha256=6d028e80bc1320b054bb584a4f1622820b493a5c6fded255f455c77acc378b0e
#   Stored in directory: /root/.cache/pip/wheels/e8/81/8f/29aafd7d671a4e9db4e976d71728870173f0b3f48ccba0bc32
# Successfully built pandarallel
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def extract_urls_topic(url):
    try:
      coverpage = requests.get(url).content
      soup = BeautifulSoup(coverpage, 'html.parser')
     
      rows = []

      for link in soup.find_all('h2', class_='title'):   
        rows.append(link.a['href'])

    except:
      rows = 'error'
      
    return rows

# %%
pandarallel.initialize(nb_workers= 30, progress_bar=True)
df = pd.DataFrame(range(1,3527),columns = ['page'])
url_str=''

#politics
for i in range(0,3526) :
    url_str='https://en.mercopress.com/politics?p='+str(i)
    df.page[i] = url_str

df['rows']=df['page'].parallel_apply(extract_urls_topic)
df = df[df.rows.str.len()!=0].reset_index(drop=True)
df = df.explode('rows', ignore_index=True)
df=df.drop_duplicates(subset='rows')
df = df.dropna()
print(df)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/mercopress.brazil/url.csv',index=False)
# Out:
# INFO: Pandarallel will run on 30 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# ...
#                                             page  \
# 0         https://en.mercopress.com/politics?p=0
# 2         https://en.mercopress.com/politics?p=2
# 3         https://en.mercopress.com/politics?p=2
# 4         https://en.mercopress.com/politics?p=2
# 5         https://en.mercopress.com/politics?p=2
# ...                                          ...
# 35228  https://en.mercopress.com/politics?p=3524
# 35229  https://en.mercopress.com/politics?p=3524
# 35230  https://en.mercopress.com/politics?p=3524
# 35231  https://en.mercopress.com/politics?p=3524
# 35232  https://en.mercopress.com/politics?p=3525
#
#                                                                                                                                                         rows
# ...
